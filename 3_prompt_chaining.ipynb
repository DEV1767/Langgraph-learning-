# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langgraph.graph import StateGraph,START,END
from typing import TypedDict
from dotenv import load_dotenv

# %%
load_dotenv()

model = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    temperature=0
)

# %%
class BlogState(TypedDict):
     title:str
     outline:str
     content:str

# %%
def create_outline(state:BlogState)->BlogState:
    
    title=state['title']
    
    prompt=f"Generate a detailed outline for a blog on the topic-{title}"
    outline=model.invoke(prompt).content
    
    state['outline']=outline
    
    return state

# %%
def create_blog(state:BlogState)->BlogState:
    title=state['title']
    outline=state['outline']
    
    prompt=f"Write a detailed blog on the title-{title} using the following outline\n {outline}"
    
    content=model.invoke(prompt).content
    
    state['content']=content
    
    return state

# %%
graph=StateGraph(BlogState)

graph.add_node('create_outline',create_outline)
graph.add_node('create_blog',create_blog)

graph.add_edge(START,'create_outline')
graph.add_edge('create_outline','create_blog')
graph.add_edge('create_blog',END)


workflow=graph.compile()

# %%
initial_state={'title':'Rise of AI in india'}

final_state=workflow.invoke(initial_state)

print(final_state)
# Out:
# {'title': 'Rise of AI in india', 'outline': 'Here\'s a detailed outline for a blog post on "The Rise of AI in India," designed to be informative, engaging, and well-structured for a blog audience.\n\n---\n\n## Blog Title Options:\n\n*   **The AI Awakening: Charting the Rise of Artificial Intelligence in India**\n*   **India\'s AI Ascent: Navigating the Digital Frontier**\n*   **From Code to Consciousness: How India is Embracing the AI Revolution**\n*   **The Next Tech Giant? Unpacking India\'s Rapid AI Growth**\n\n---\n\n## Detailed Blog Outline: The AI Awakening: Charting the Rise of Artificial Intelligence in India\n\n**I. Introduction: The Dawn of a New Era**\n\n*   **A. Hook:** Start with a compelling statement about the global AI revolution and its transformative power.\n    *   *Example:* "Artificial Intelligence is no longer a futuristic concept confined to sci-fi novels; it\'s a tangible force reshaping industries, economies, and daily lives across the globe."\n*   **B. India\'s Unique Position:** Briefly introduce India as a significant player in this global shift.\n    *   Highlight its large talent pool, digital infrastructure, and unique challenges/opportunities.\n*   **C. Thesis Statement:** India is rapidly emerging as a key hub for AI innovation and adoption, driven by government initiatives, a vibrant startup ecosystem, and a massive digital consumer base, poised to solve both local and global problems.\n*   **D. What to Expect:** Briefly outline the key areas the blog will cover (driving forces, key sectors, challenges, future outlook).\n\n**II. The Driving Forces Behind India\'s AI Boom**\n\n*   **A. Government Initiatives & Policy Push:**\n    *   **1. National AI Strategy:** NITI Aayog\'s "AI for All" vision.\n    *   **2. Digital India & Make in India:** Creating a fertile ground for tech adoption and indigenous development.\n    *   **3. Data Accessibility:** Initiatives like India Stack (Aadhaar, UPI) generating vast amounts of data.\n    *   **4. Funding & Research:** Government grants, AI research centers.\n*   **B. A Robust Talent Pool:**\n    *   **1. STEM Graduates:** India\'s massive output of engineers and computer scientists.\n    *   **2. IT Services Legacy:** A strong foundation in software development and data management.\n    *   **3. Growing Data Science & ML Expertise:** Increasing demand and specialized courses.\n*   **C. Vibrant Startup Ecosystem & Investment:**\n    *   **1. Proliferation of AI Startups:** Focus on diverse sectors (healthcare, agri-tech, fintech).\n    *   **2. Increased Venture Capital Funding:** Domestic and international investment pouring into AI ventures.\n    *   **3. Innovation Hubs:** Bengaluru, Hyderabad, Delhi-NCR as major centers.\n*   **D. Digital Infrastructure & Adoption:**\n    *   **1. High Internet Penetration:** Affordable data and widespread smartphone usage.\n    *   **2. UPI & Digital Payments:** Creating a data-rich environment for financial AI.\n    *   **3. Cloud Computing Adoption:** Enabling scalable AI solutions.\n*   **E. Large & Diverse Market:**\n    *   **1. Unique Problems:** AI solutions tailored for India\'s specific challenges (e.g., rural healthcare, multilingual communication).\n    *   **2. Massive Consumer Base:** Opportunities for personalized services and recommendations.\n\n**III. Key Sectors Embracing AI in India**\n\n*   **A. Healthcare:**\n    *   **1. Diagnostics:** AI-powered image analysis (radiology, pathology), early disease detection.\n    *   **2. Drug Discovery & Development:** Accelerating research, personalized medicine.\n    *   **3. Telemedicine & Remote Monitoring:** Expanding access to healthcare in rural areas.\n    *   **4. Predictive Analytics:** Outbreak prediction, patient risk assessment.\n*   **B. Agriculture (AgriTech):**\n    *   **1. Crop Yield Prediction:** Using satellite imagery and weather data.\n    *   **2. Pest & Disease Detection:** AI-powered image recognition for early intervention.\n    *   * ...

# %%
print(final_state['outline'])
# Out:
# Here's a detailed outline for a blog post on "The Rise of AI in India," designed to be informative, engaging, and well-structured for a blog audience.
#
# ---
#
# ## Blog Title Options:
#
# *   **The AI Awakening: Charting the Rise of Artificial Intelligence in India**
# *   **India's AI Ascent: Navigating the Digital Frontier**
# *   **From Code to Consciousness: How India is Embracing the AI Revolution**
# *   **The Next Tech Giant? Unpacking India's Rapid AI Growth**
#
# ---
#
# ## Detailed Blog Outline: The AI Awakening: Charting the Rise of Artificial Intelligence in India
#
# **I. Introduction: The Dawn of a New Era**
#
# *   **A. Hook:** Start with a compelling statement about the global AI revolution and its transformative power.
#     *   *Example:* "Artificial Intelligence is no longer a futuristic concept confined to sci-fi novels; it's a tangible force reshaping industries, economies, and daily lives across the globe."
# *   **B. India's Unique Position:** Briefly introduce India as a significant player in this global shift.
#     *   Highlight its large talent pool, digital infrastructure, and unique challenges/opportunities.
# *   **C. Thesis Statement:** India is rapidly emerging as a key hub for AI innovation and adoption, driven by government initiatives, a vibrant startup ecosystem, and a massive digital consumer base, poised to solve both local and global problems.
# *   **D. What to Expect:** Briefly outline the key areas the blog will cover (driving forces, key sectors, challenges, future outlook).
#
# **II. The Driving Forces Behind India's AI Boom**
#
# *   **A. Government Initiatives & Policy Push:**
#     *   **1. National AI Strategy:** NITI Aayog's "AI for All" vision.
#     *   **2. Digital India & Make in India:** Creating a fertile ground for tech adoption and indigenous development.
#     *   **3. Data Accessibility:** Initiatives like India Stack (Aadhaar, UPI) generating vast amounts of data.
#     *   **4. Funding & Research:** Government grants, AI research centers.
# *   **B. A Robust Talent Pool:**
#     *   **1. STEM Graduates:** India's massive output of engineers and computer scientists.
#     *   **2. IT Services Legacy:** A strong foundation in software development and data management.
#     *   **3. Growing Data Science & ML Expertise:** Increasing demand and specialized courses.
# *   **C. Vibrant Startup Ecosystem & Investment:**
#     *   **1. Proliferation of AI Startups:** Focus on diverse sectors (healthcare, agri-tech, fintech).
#     *   **2. Increased Venture Capital Funding:** Domestic and international investment pouring into AI ventures.
#     *   **3. Innovation Hubs:** Bengaluru, Hyderabad, Delhi-NCR as major centers.
# *   **D. Digital Infrastructure & Adoption:**
#     *   **1. High Internet Penetration:** Affordable data and widespread smartphone usage.
#     *   **2. UPI & Digital Payments:** Creating a data-rich environment for financial AI.
#     *   **3. Cloud Computing Adoption:** Enabling scalable AI solutions.
# *   **E. Large & Diverse Market:**
#     *   **1. Unique Problems:** AI solutions tailored for India's specific challenges (e.g., rural healthcare, multilingual communication).
#     *   **2. Massive Consumer Base:** Opportunities for personalized services and recommendations.
#
# **III. Key Sectors Embracing AI in India**
#
# *   **A. Healthcare:**
#     *   **1. Diagnostics:** AI-powered image analysis (radiology, pathology), early disease detection.
#     *   **2. Drug Discovery & Development:** Accelerating research, personalized medicine.
#     *   **3. Telemedicine & Remote Monitoring:** Expanding access to healthcare in rural areas.
#     *   **4. Predictive Analytics:** Outbreak prediction, patient risk assessment.
# *   **B. Agriculture (AgriTech):**
#     *   **1. Crop Yield Prediction:** Using satellite imagery and weather data.
#     *   **2. Pest & Disease Detection:** AI-powered image recognition for early intervention.
#     *   **3. Precision Farming:** Optimized irrigation, fertilizer application.
#     *   **4. Supply Chain Optimization:** Reducing waste, improving market access for farmers.
# *   **C. Finance (FinTech):**
#     *   **1. Fraud Detection:** Real-time anomaly detection in transactions.
#     *   **2. Credit Scoring & Risk Assessment:** More accurate and inclusive lending.
#     *   **3. Personalized Banking:** AI-driven recommendations, chatbots for customer service.
#     *   **4. Algorithmic Trading:** For financial markets.
# *   **D. Education (EdTech):**
#     *   **1. Personalized Learning Paths:** Adaptive content based on student performance.
#     *   **2. Smart Content Creation:** AI-generated learning materials.
#     *   **3. Administrative Automation:** Grading, scheduling, student support.
# *   **E. E-commerce & Retail:**
#     *   **1. Recommendation Engines:** Personalized product suggestions.
#     *   **2. Supply Chain & Logistics Optimization:** Inventory management, delivery route planning.
#     *   **3. Customer Service Chatbots:** 24/7 support.
# *   **F. Manufacturing & Automotive:**
#     *   **1. Predictive Maintenance:** Reducing downtime, optimizing machinery performance.
#     *   **2. Quality Control:** AI-powered visual inspection.
#     *   **3. Automation & Robotics:** Enhancing efficiency and safety.
# *   **G. Public Services & Smart Cities:**
#     *   **1. Traffic Management:** Optimizing flow, reducing congestion.
#     *   **2. Waste Management:** Route optimization, resource allocation.
#     *   **3. Grievance Redressal:** AI-powered chatbots for citizen services.
#
# **IV. India's Unique Contributions & Innovations in AI**
#
# *   **A. AI for Social Good:** Focus on solving problems like poverty, illiteracy, and healthcare access.
# *   **B. Multilingual AI:** Developing solutions for India's diverse linguistic landscape (e.g., voice assistants in regional languages).
# *   **C. Low-Cost & Scalable Solutions:** Innovating to make AI accessible and affordable for a large population.
# *   **D. Data-Driven Governance:** Leveraging AI for public policy, resource allocation, and citizen engagement.
#
# **V. Challenges and Roadblocks on the AI Journey**
#
# *   **A. Data Privacy & Security Concerns:**
#     *   **1. Regulatory Framework:** Need for robust data protection laws (e.g., DPDP Act).
#     *   **2. Ethical Use of Data:** Ensuring responsible collection and usage.
# *   **B. Skill Gap & Workforce Reskilling:**
#     *   **1. Need for Advanced AI Skills:** Beyond basic programming, specialized ML/DL expertise.
#     *   **2. Impact on Traditional Jobs:** Preparing the workforce for AI-driven automation.
# *   **C. Infrastructure Gaps:**
#     *   **1. Rural Connectivity:** Bridging the digital divide for equitable AI access.
#     *   **2. Computing Power:** Need for more robust cloud infrastructure and supercomputing capabilities.
# *   **D. Ethical AI & Bias:**
#     *   **1. Algorithmic Bias:** Ensuring fairness and preventing discrimination in AI models.
#     *   **2. Transparency & Explainability:** Making AI decisions understandable.
# *   **E. Funding & Investment Disparities:** While growing, certain sectors or regions may still lack adequate investment.
#
# **VI. The Future of AI in India: A Glimpse Ahead**
#
# *   **A. Continued Growth & Investment:** Expecting more unicorns, increased FDI, and domestic funding.
# *   **B. Policy Evolution:** Maturing regulatory framework for data, ethics, and intellectual property.
# *   **C. Global AI Hub:** India's potential to become a leading exporter of AI talent and solutions.
# *   **D. Human-AI Collaboration:** Focus on augmentation rather than pure automation, creating new job roles.
# *   **E. Responsible AI Development:** Emphasis on building ethical, transparent, and inclusive AI systems.
# *   **F. Deep Tech & Research:** Increased focus on foundational AI research, quantum AI, and advanced robotics.
#
# **VII. Conclusion: India's AI Odyssey**
#
# *   **A. Recap:** Briefly summarize India's rapid AI growth, its diverse applications across sectors, and its unique contributions.
# *   **B. Reinforce Thesis:** Reiterate India's pivotal and growing role in the global AI landscape.
# *   **C. Forward-Looking Statement:** End with an optimistic yet realistic outlook on India's AI future, emphasizing its potential to drive economic growth and societal progress.
# *   **D. Call to Action/Thought Provoker:**
#     *   *Example:* "As India continues its AI odyssey, the journey promises both immense opportunities and complex challenges. How do you envision AI shaping the future of India, and what role do you believe we all play in ensuring its responsible and inclusive growth?"
#
# ---
