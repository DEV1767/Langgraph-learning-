# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langgraph.graph import StateGraph,START,END
from typing import TypedDict
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
model = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    temperature=0
)

# %%
class LLmState(TypedDict):
    question:str
    answer:str

# %%
def llm_qa(state:LLmState)->LLmState:
    
    question=state['question']
    
    prompt=f"Answer the following queation{question}"
    
    answer=model.invoke(prompt).content
    
    state['answer']=answer
    
    return state

# %%
graph=StateGraph(LLmState)

graph.add_node('llm_qa',llm_qa)

graph.add_edge(START,'llm_qa')
graph.add_edge('llm_qa',END)


workflow=graph.compile()

# %%
initial_state={'question':'How far is moon from the earth ?'}

final_state=workflow.invoke(initial_state)

print(final_state)
# Out:
# {'question': 'How far is moon from the earth ?', 'answer': "The average distance from the Earth to the Moon is approximately **384,400 kilometers (238,900 miles)**.\n\nHowever, this distance isn't constant because the Moon's orbit around the Earth is elliptical, not a perfect circle.\n\n*   **Perigee (closest point):** About 363,104 kilometers (225,623 miles)\n*   **Apogee (farthest point):** About 405,696 kilometers (252,088 miles)\n\nLight from the Moon takes about **1.3 seconds** to reach Earth."}
